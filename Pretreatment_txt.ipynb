# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/Othercomputers/내 노트북/googleDrive/BMO-Voice
# Out:
# [Errno 2] No such file or directory: 'drive/Othercomputers/내 노트북/googleDrive/BMO-Voice'
# /content/drive/Othercomputers/내 노트북/googleDrive/BMO-Voice/kss

# %%
cd kss
# Out:
# [Errno 2] No such file or directory: 'kss'
# /content/drive/Othercomputers/내 노트북/googleDrive/BMO-Voice/kss

# %%
address = []
text = []

f = open('transcript.v.1.4.txt', 'r')

while True:
    line = f.readline()
    if not line:
        break
    a = line.split('|')
    address.append(a[0])
    text.append(a[1])

f.close()

# %%
text

# %%
w = open("new.txt", 'w')

for i in range(len(text)):
    w.write(address[i] + '|' + text[i] + '\n')
w.close()

# %%
address = []
text = []

f = open('new.txt', 'r')

while True:
    line = f.readline()
    if not line:
        break
    a = line.split('|')
    address.append(a[0])
    text.append(a[1])

f.close()

# %%
w = open("train.txt", 'w')

for i in range(11000):
    w.write('D:\googleDrive\BMO-Voice\kss' + address[i] + '|' + text[i])

w.close()

w = open("dev.txt", 'w')
for i in range(11000, 12854):
    w.write('D:\googleDrive\BMO-Voice\kss' + address[i] + '|' + text[i])

w.close()

# %%
len(text)
# Out:
# 12854
